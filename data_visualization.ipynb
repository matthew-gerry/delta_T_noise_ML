# %% [markdown]
# A notebook for exploring and visualizing the Delta T shot noise data we have

# %%
import numpy as np
# import matplotlib
# matplotlib.rcParams.update({'font.size': 11})
import matplotlib.pyplot as plt
import pandas as pd

# Set pyplot global params to get nice fonts
plt.rcParams["mathtext.fontset"] = "cm" # Match Latex font as closely as possible
plt.rcParams['font.size'] = '14' # Globally set font size of plots
plt.rcParams["font.family"] = "serif"
plt.rcParams['font.serif'] = ['cmr10']
plt.rcParams['axes.unicode_minus'] = False # NEEDED FOR MINUS SIGNS TO RENDER PROPERLY but can't give me back that hour of my life in 2021

# Define constants
g0 = 7.748092*10**(-5) # C^2/J/s, conductance quantum
kB = 1.380649*10**(-23) # J/K, Boltzmann constant

# %%
# Read delta T shot noise data
df = pd.read_csv('../GNoiseData_complete.csv')

# Add rescaled data to dataframe (G already scaled by G0)
df['DeltaT_scaled'] = df['DeltaT']/df['T']
df['S_scaled'] = df['S']/(g0 * kB * df['T'])

# %% [markdown]
# Different approaches towards visualizing the data

# %%
# All the data, colour scale set by deltaT/T

plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT_scaled"])
plt.xlim([0,8.3])
plt.ylim([0, 2.5])
plt.xlabel("$G/G_0$")
plt.ylabel("$S/G_0k_BT$")
# plt.legend()
plt.colorbar(label="$\Delta T/T$")
plt.show()

plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT_scaled"])
plt.xlim([0,1])
plt.ylim([0, 0.25])
plt.xlabel("$G/G_0$")
plt.ylabel("$S/G_0k_BT$")
# plt.legend()
plt.colorbar(label="$\Delta T/T$")
plt.show()
# Out:
# /tmp/ipykernel_4309/4102682239.py:3: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT_scaled"])
# /tmp/ipykernel_4309/4102682239.py:9: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label="$\Delta T/T$")
# /tmp/ipykernel_4309/4102682239.py:12: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT_scaled"])
# /tmp/ipykernel_4309/4102682239.py:18: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label="$\Delta T/T$")

# %%
# Scatter of G and S_scaled with colour scale set by unscaled, rather than scaled, Delta T values

plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT"])
plt.xlim([0,8.3])
plt.ylim([0, 2.5])
plt.xlabel("$G/G_0$")
plt.ylabel("$S/G_0k_BT$")
plt.colorbar(label="$\Delta T$")
plt.show()

plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT"])
plt.xlim([0,1])
plt.ylim([0, 0.25])
plt.xlabel("$G/G_0$")
plt.ylabel("$S/G_0k_BT$")
plt.colorbar(label="$\Delta T$")
plt.show()
# Out:
# /tmp/ipykernel_4309/3337396090.py:3: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT"])
# /tmp/ipykernel_4309/3337396090.py:8: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label="$\Delta T$")
# /tmp/ipykernel_4309/3337396090.py:11: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["DeltaT"])
# /tmp/ipykernel_4309/3337396090.py:16: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label="$\Delta T$")

# %%
# Scatter plots of G and S_scaled with the average temperature T setting the colour scale rather than delta T

plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["T"])
plt.xlim([0,8.3])
plt.ylim([0, 2.5])
plt.xlabel("$G/G_0$")
plt.ylabel("$S/G_0k_BT$")
plt.colorbar(label="$T$")
plt.show()

plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["T"])
plt.xlim([0,1])
plt.ylim([0, 0.25])
plt.xlabel("$G/G_0$")
plt.ylabel("$S/G_0k_BT$")
plt.colorbar(label="$T$")
plt.show()
# Out:
# /tmp/ipykernel_4309/4261295870.py:3: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["T"])
# /tmp/ipykernel_4309/4261295870.py:8: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label="$T$")
# /tmp/ipykernel_4309/4261295870.py:11: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.scatter(df["G"], df["S_scaled"], s=0.4, c=df["T"])
# /tmp/ipykernel_4309/4261295870.py:16: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(label="$T$")

# %%
# Scatter plots of G and S_scaled with the average temperature T setting the colour scale
# Showing the low-G region as a zoomed inset

fig, ax = plt.subplots()

sctr = ax.scatter(df["G"], df["S_scaled"], s=0.4, c=df["T"])
ax.set_xlim([0,8.3])
ax.set_ylim([0, 1.9])
ax.set_xlabel("$G/G_0$", fontsize=14)
ax.set_ylabel("$S/G_0k_BT$", fontsize=14)
plt.colorbar(sctr, label="$T\; (K)$")
# plt.show()

x1, x2, y1, y2 = 0.0, 1.0, 0.0, 0.25 # Boundaries of inset

axins = ax.inset_axes([0.07, 0.45, 0.45, 0.5], xlim=(x1, x2), ylim=(y1, y2), xticklabels=[], yticklabels=[])
# axins = ax.inset_axes([0.05, 0.5, 0.4, 0.45], xlim=(x1, x2), ylim=(y1, y2), xticklabels=[0.2, 0.4, 0.6, 0.8], yticklabels=[0.05,0.1,0.15,0.2])
axins.scatter(df["G"], df["S_scaled"], s=0.4, c=df["T"])
# plt.xlim([0,1])
# plt.ylim([0, 0.25])
# plt.xlabel("$G/G_0$")
# plt.ylabel("$S/G_0k_BT$")
# plt.colorbar(label="$T$")
ax.indicate_inset_zoom(axins, edgecolor='k')
plt.show()
# Out:
# /tmp/ipykernel_4309/425138605.py:4: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots()
# /tmp/ipykernel_4309/425138605.py:11: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.colorbar(sctr, label="$T\; (K)$")
# /tmp/ipykernel_4309/425138605.py:16: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   axins = ax.inset_axes([0.07, 0.45, 0.45, 0.5], xlim=(x1, x2), ylim=(y1, y2), xticklabels=[], yticklabels=[])

# %%
# Just out of curiousity, let's plot Delta T as a function of T, to see what the non-physical relation is that the data suggests exists between the two

df_T_pairs = df[["T","DeltaT"]].drop_duplicates().sort_values("T")
# plt.plot(df_T_pairs["T"], df_T_pairs["DeltaT"]/df_T_pairs["T"])
plt.plot(df_T_pairs["T"], df_T_pairs["DeltaT"], 'x')
# plt.plot(df_T_pairs["DeltaT"], df_T_pairs["T"], 'x')
plt.xlabel("$T$")
plt.ylabel("$\Delta T$")
plt.show()
# Out:
# /tmp/ipykernel_4309/1109737323.py:5: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(df_T_pairs["T"], df_T_pairs["DeltaT"], 'x')

# %% [markdown]
# Below we plot some histograms of the predictions made by our model, when trained on synthetic data, on both the synthetic data and the real data.

# %%
# Import training (synthetic) and testing (real) data with predicted delta T values, identify the sets of independent Delta T values

df_synth = pd.read_csv('../training_data_with_prediction_sample.csv')
df_real = pd.read_csv('../testing_data_with_prediction_sample.csv')

unique_dT_vals_s = np.sort(np.unique(df_synth['DeltaT']))
unique_dT_vals_r = np.sort(np.unique(df_real['DeltaT']))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Import training (synthetic) and testing (real) data with predicted delta T values, identify the sets of independent Delta T values
# ----> 3 df_synth = pd.read_csv('../training_data_with_prediction_sample.csv')
#       4 df_real = pd.read_csv('../testing_data_with_prediction_sample.csv')
#       6 unique_dT_vals_s = np.sort(np.unique(df_synth['DeltaT']))
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../training_data_with_prediction_sample.csv'

# %%
unique_dT_vals_r
# Out:
# array([ 0.1, 10. , 12.6, 12.8, 15.3, 16. , 18.5, 20. , 23. , 24.3, 28.1])

# %%
# Plot a histogram of predicted Delta T values given a true value - synthetic (training) data

# Choose a set of indices at which to select out unique delta T values
dT_indices = [0, 6, 12, 18, 24, 29]

fig = plt.figure(figsize=(13, 7))
axs = fig.subplots(2,3)
for i in range(len(dT_indices)):
    dT = unique_dT_vals_s[dT_indices[i]]

    prediction_mean = df_synth.loc[df_synth['DeltaT']==dT, 'DeltaT_predicted'].mean()

    hg = axs[int(i>2),i%3].hist(df_synth.loc[df_synth['DeltaT']==dT, 'DeltaT_predicted'], bins=50, density=True)
    axs[int(i>2),i%3].vlines([dT, prediction_mean], 0, 1.1*max(hg[0]), color=['red', 'green'])
    axs[int(i>2),i%3].set_ylim([0, 1.1*max(hg[0])])
    axs[int(i>2),i%3].set_title("$\Delta T = "+str(round(dT, 1))+r", \langle \Delta T_{pred}\rangle = $"+str(round(prediction_mean, 1)))

fig.suptitle("Synthetic data - performance on training set")
plt.show()

# %%
# Now the same for the test data

# Choose a set of indices at which to select out unique delta T values
dT_indices = [1, 2, 4, 6, 8, 10]

fig = plt.figure(figsize=(13, 7))
axs = fig.subplots(2,3)
for i in range(len(dT_indices)):
    dT = unique_dT_vals_r[dT_indices[i]]

    prediction_mean = df_real.loc[df_real['DeltaT']==dT, 'DeltaT_predicted'].mean()

    hg = axs[int(i>2),i%3].hist(df_real.loc[df_real['DeltaT']==dT, 'DeltaT_predicted'], bins=50, density=True)
    axs[int(i>2),i%3].vlines([dT, prediction_mean], 0, 1.1*max(hg[0]), color=['red', 'green'])
    axs[int(i>2),i%3].set_ylim([0, 1.1*max(hg[0])])
    axs[int(i>2),i%3].set_title("$\Delta T = "+str(round(dT, 2))+r", \langle \Delta T_{pred}\rangle = $"+str(round(prediction_mean, 1)))


fig.suptitle("Experimental data - performance on testing set")
plt.show()
